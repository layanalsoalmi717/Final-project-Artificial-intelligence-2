# %% [markdown]
# <a href="https://colab.research.google.com/github/layanalsoalmi717/Final-project-Artificial-intelligence-2/blob/main/file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_package = """numpy
pandas
matplotlib
seaborn
sklearn
tensorflow.keras"""
with open("requirements.txt", "w") as f:
    f.write(python_package)
print("done")
# Out:
# done
